# %%
import pandas as pd

# %%
# !python train.py --dataset citeseer --gnnlayers 3 --upth_st 0.011 --lowth_st 0.001 --upth_ed 0.1  --lowth_ed 0.5
# Out:
# Using GPU
# Using citeseer dataset
# Laplacian Smoothing...
# Start Training...
# Epoch: 10, train_loss_gae=0.62630, time=0.32945
# Epoch: 20, train_loss_gae=0.57042, time=0.34466
# Epoch: 30, train_loss_gae=0.55174, time=0.42368
# Epoch: 40, train_loss_gae=0.54410, time=0.47100
# Epoch: 50, train_loss_gae=0.53449, time=0.62811
# Epoch: 60, train_loss_gae=0.52790, time=0.67441
# Epoch: 70, train_loss_gae=0.52311, time=0.53344
# Epoch: 80, train_loss_gae=0.52007, time=0.80076
# Epoch: 90, train_loss_gae=0.51861, time=0.64331
# Epoch: 100, train_loss_gae=0.51666, time=0.76877
# Epoch: 110, train_loss_gae=0.51807, time=0.56524
# Epoch: 120, train_loss_gae=0.51664, time=0.70636
# Epoch: 130, train_loss_gae=0.51733, time=0.59651
# Epoch: 140, train_loss_gae=0.51707, time=0.65927
# Epoch: 150, train_loss_gae=0.51808, time=0.54948
# Epoch: 160, train_loss_gae=0.51733, time=0.67460
# Epoch: 170, train_loss_gae=0.51588, time=0.51734
# Epoch: 180, train_loss_gae=0.51805, time=0.75338
# ...

# %%
from clustering_metric import clustering_metrics
import numpy as np 
from tqdm import tqdm

# %%
hidden = np.load('hidden_399.npy')
true = np.load('true_399.npy')

# %%
x = clustering_metrics(hidden,true)

# %%
x.plotClusters(tqdm,hidden,true)
# Out:
# Start plotting using TSNE...
# Finished plotting
